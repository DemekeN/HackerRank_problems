# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())
arr = map(int, input().split())
srt =set(arr)
print(sorted(list(srt))[-2])
# Out:
# 5
# 2 3 6 6 5
# 5

# %%
n = int(input())
arr = map(int, input().split())
print(sorted(list(set(arr)))[-2])
# Out:
# 8
# 3 4 5 6 6 6 7 7
# 6
