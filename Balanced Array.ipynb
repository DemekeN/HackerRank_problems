# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solve(a):
    i = int(n/2)
    sum1 = sum(a[0:i])
    sum2 = sum(a[i:])
    if sum1 ==sum2:
        return 0
    else:
        return (abs(sum1-sum2))

n = int(input().strip())
a = list(map(int, input().strip().split(' ')))
result = solve(a)
print(result)
# Out:
# 6
# 1 2 5 2 4 2
# 0
