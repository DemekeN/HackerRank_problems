# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import itertools
N = int(input())
letters = input().split() # N spaceseparated lowercase English letters 
K = int(input())
total =0 
a_count = 0

for comb in itertools.combinations(letters, K):
    if 'a' in comb:
        a_count+=1
    total+=1
print('{:f}'.format(a_count/total))
# Out:
# 4
# a a c d
# 2
# 0.833333
